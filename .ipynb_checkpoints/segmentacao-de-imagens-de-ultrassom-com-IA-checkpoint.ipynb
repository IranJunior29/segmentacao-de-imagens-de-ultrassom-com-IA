# %% [markdown]
# # <font color='blue'>Análise de Imagens com Inteligência Artificial</font>
# ### <font color='blue'>Segmentação de Imagens de Ultrassom com Inteligência Artificial</font>

# %% [markdown]
# ## Instalando e Carregando os Pacotes

# %%
from platform import python_version
print('Versão da Linguagem Python Usada Neste Jupyter Notebook:', python_version())
# Out:
# Versão da Linguagem Python Usada Neste Jupyter Notebook: 3.11.4

# %%
# !pip install -q -U watermark

# %%
# %env TF_CPP_MIN_LOG_LEVEL=3
# Out:
# env: TF_CPP_MIN_LOG_LEVEL=3

# %%
# !pip install -q tensorflow

# %%
# !pip install scikit-learn==1.3.0
# !pip install pandas==1.5.3
# !pip install matplotlib==3.7.2
# !pip install scikit-image==0.20.0
# Out:
# Requirement already satisfied: scikit-learn==1.3.0 in /home/iran/anaconda3/envs/python3.11.4/lib/python3.11/site-packages (1.3.0)
# Requirement already satisfied: numpy>=1.17.3 in /home/iran/anaconda3/envs/python3.11.4/lib/python3.11/site-packages (from scikit-learn==1.3.0) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in /home/iran/anaconda3/envs/python3.11.4/lib/python3.11/site-packages (from scikit-learn==1.3.0) (1.12.0)
# Requirement already satisfied: joblib>=1.1.1 in /home/iran/anaconda3/envs/python3.11.4/lib/python3.11/site-packages (from scikit-learn==1.3.0) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/iran/anaconda3/envs/python3.11.4/lib/python3.11/site-packages (from scikit-learn==1.3.0) (3.3.0)
# Requirement already satisfied: pandas==1.5.3 in /home/iran/anaconda3/envs/python3.11.4/lib/python3.11/site-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/iran/anaconda3/envs/python3.11.4/lib/python3.11/site-packages (from pandas==1.5.3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/iran/anaconda3/envs/python3.11.4/lib/python3.11/site-packages (from pandas==1.5.3) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /home/iran/anaconda3/envs/python3.11.4/lib/python3.11/site-packages (from pandas==1.5.3) (1.26.4)
# Requirement already satisfied: six>=1.5 in /home/iran/anaconda3/envs/python3.11.4/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas==1.5.3) (1.16.0)
# Requirement already satisfied: matplotlib==3.7.2 in /home/iran/anaconda3/envs/python3.11.4/lib/python3.11/site-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/iran/anaconda3/envs/python3.11.4/lib/python3.11/site-packages (from matplotlib==3.7.2) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/iran/anaconda3/envs/python3.11.4/lib/python3.11/site-packages (from matplotlib==3.7.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/iran/anaconda3/envs/python3.11.4/lib/python3.11/site-packages (from matplotlib==3.7.2) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/iran/anaconda3/envs/python3.11.4/lib/python3.11/site-packages (from matplotlib==3.7.2) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /home/iran/anaconda3/envs/python3.11.4/lib/python3.11/site-packages (from matplotlib==3.7.2) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/iran/anaconda3/envs/python3.11.4/lib/python3.11/site-packages (from matplotlib==3.7.2) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/iran/anaconda3/envs/python3.11.4/lib/python3.11/site-packages (from matplotlib==3.7.2) (10.2.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /home/iran/anaconda3/envs/python3.11.4/lib/python3.11/site-packages (from matplotlib==3.7.2) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/iran/anaconda3/envs/python3.11.4/lib/python3.11/site-packages (from matplotlib==3.7.2) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/iran/anaconda3/envs/python3.11.4/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib==3.7.2) (1.16.0)
# Requirement already satisfied: scikit-image==0.20.0 in /home/iran/anaconda3/envs/python3.11.4/lib/python3.11/site-packages (0.20.0)
# Requirement already satisfied: numpy>=1.21.1 in /home/iran/anaconda3/envs/python3.11.4/lib/python3.11/site-packages (from scikit-image==0.20.0) (1.26.4)
# Requirement already satisfied: scipy>=1.8 in /home/iran/anaconda3/envs/python3.11.4/lib/python3.11/site-packages (from scikit-image==0.20.0) (1.12.0)
# Requirement already satisfied: networkx>=2.8 in /home/iran/anaconda3/envs/python3.11.4/lib/python3.11/site-packages (from scikit-image==0.20.0) (3.2.1)
# Requirement already satisfied: pillow>=9.0.1 in /home/iran/anaconda3/envs/python3.11.4/lib/python3.11/site-packages (from scikit-image==0.20.0) (10.2.0)
# Requirement already satisfied: imageio>=2.4.1 in /home/iran/anaconda3/envs/python3.11.4/lib/python3.11/site-packages (from scikit-image==0.20.0) (2.34.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /home/iran/anaconda3/envs/python3.11.4/lib/python3.11/site-packages (from scikit-image==0.20.0) (2024.2.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /home/iran/anaconda3/envs/python3.11.4/lib/python3.11/site-packages (from scikit-image==0.20.0) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/iran/anaconda3/envs/python3.11.4/lib/python3.11/site-packages (from scikit-image==0.20.0) (23.1)
# Requirement already satisfied: lazy_loader>=0.1 in /home/iran/anaconda3/envs/python3.11.4/lib/python3.11/site-packages (from scikit-image==0.20.0) (0.3)

# %%
# Imports
import os
import re
import sklearn
import pandas as pd
import matplotlib.pyplot as plt
import random
from PIL import Image
import numpy as np
import skimage
from sklearn.model_selection import train_test_split
import tensorflow as tf

# %%
# Versões dos pacotes usados neste jupyter notebook
# %reload_ext watermark
# %watermark -a "Data Science Academy" --iversions
# Out:
# Author: Data Science Academy
#
# numpy     : 1.26.4
# matplotlib: 3.7.2
# tensorflow: 2.16.1
# re        : 2.2.1
# sklearn   : 1.3.0
# skimage   : 0.20.0
# PIL       : 10.2.0
# pandas    : 1.5.3

# %% [markdown]
# ## Organizando as Imagens em Disco

# %%
# Dados retirado de 'https://www.kaggle.com/competitions/ultrasound-nerve-segmentation/overview'
# Carrega o arquivo CSV
df = pd.read_csv('dados/train_masks.csv')

# %%
df.shape
# Out:
# (5635, 3)

# %%
df.head()
# Out:
#    subject  img                                             pixels
# 0        1    1  168153 9 168570 15 168984 22 169401 26 169818 ...
# 1        1    2  96346 7 96762 16 97179 27 97595 35 98012 40 98...
# 2        1    3  121957 2 122365 26 122784 28 123202 31 123618 ...
# 3        1    4  110980 9 111393 21 111810 33 112228 43 112647 ...
# 4        1    5                                                NaN

# %%
# Caminho para imagens de treino e teste
training_path = os.listdir('dados/train/')
test_path = os.listdir('dados/test/')

# %%
print(len(training_path), len(test_path))
# Out:
# 11270 5508

# %%
# Compila uma expressão regular que busca por uma ou mais sequências numéricas.
reg = re.compile("[0-9]+")

# Mapeia cada item em 'training_path', procura por uma sequêncai numérica e retorna o primeiro match.
temp1 = list(map(lambda x: reg.match(x).group(), training_path))

# Converte todos os itens de 'temp1' (que são strings) para interios.
temp1 = list(map(int, temp1))

# Mapeia cada item em 'training_path', divide a string pelo caractere '_', pega o segundo item resultante,
# procura por uma sequência numérica e retorna o primeiro match.
temp2 = list(map(lambda x: reg.match(x.split("_")[1]).group(), training_path))

# Converte todos os itens de 'temp2' (que são strings) para inteiros.
temp2 = list(map(int, temp2))

# Combina 'temp1', 'temp2' e 'training_path' e ordena a combinação usando 'temp1' e 'temp2' como chaves
# de ordenação, depois pega apenas os valores de 'training_path'.
training_path = [x for _,_,x in sorted(zip(temp1, temp2, training_path))]

# Exibe os primeiros 20 itens da lista 'caminho_treino'.
training_path[:20]
# Out:
# ['1_1.tif',
#  '1_1_mask.tif',
#  '1_2.tif',
#  '1_2_mask.tif',
#  '1_3.tif',
#  '1_3_mask.tif',
#  '1_4.tif',
#  '1_4_mask.tif',
#  '1_5.tif',
#  '1_5_mask.tif',
#  '1_6.tif',
#  '1_6_mask.tif',
#  '1_7.tif',
#  '1_7_mask.tif',
#  '1_8.tif',
#  '1_8_mask.tif',
#  '1_9.tif',
#  '1_9_mask.tif',
#  '1_10.tif',
#  '1_10_mask.tif']

# %%
len(training_path)
# Out:
# 11270

# %%
# Listas
training_images = []
training_mask = []

# %%
# Itera sobre os índices e itens da lista 'training_path'.
for index, item in enumerate(training_path):
    
    # Verifica se o índice é par.
    if index % 2 == 0:
        
        # Se o índice for par, adiciona o item à lista 'training_images'.
        training_images.append(item)
    else:
        
        # Se o índice for ímpar, adiciona o item à lista 'training_mask'.
        training_mask.append(item)

# %%
print(len(training_images))
print(len(training_mask))
# Out:
# 5635
# 5635

# %%
# Plot
fig , ax = plt.subplots(5, 2, figsize = [12, 12])
fig.suptitle('Imagens dos Nervos do Pescoço')
ax[0 , 0].set_title('Imagens')
ax[0 , 1].set_title('Máscaras')

# Loop
for i in range(0, 5):
    
    # Imagem
    ind = random.randint(0, len(training_images))
    img1 = np.array(Image.open("dados/train/" + str(training_images[ind])))
    ax[i , 0].imshow(img1, cmap = 'gray')

    # Máscara
    img2 = np.array(Image.open("dados/train/" + str(training_mask[ind])))
    img2 = np.ma.masked_where(img2 == 0, img2)
    ax[i , 1].imshow(img1, cmap = 'gray' , interpolation = 'none')
    ax[i , 1].imshow(img2, cmap = 'jet', interpolation = 'none', alpha = 0.7)
    
plt.show()

# %% [markdown]
# ## Pré-Processamento das Imagens

# %%
# Cria as matrizes X e Y que serão preenchidas com as transformações de imagens e máscaras
X = np.zeros((len(training_images), 128, 128, 1), dtype = np.float32)
Y = np.zeros((len(training_mask), 128, 128, 1), dtype = np.float32)

# %% [markdown]
# > Pré-Processamento das Imagens.

# %%
# Itera sobre os índices (n) e os nomes das imagens (img_name) na lista 'training_images'.
for n, img_name in enumerate(training_images):
    
    # Carrega a imagem do diretório 'dados/train/' com o nome 'img_name' no modo escala de cinza (grayscale).
    img = tf.keras.preprocessing.image.load_img('dados/train/' + img_name, color_mode = "grayscale")
    
    # Converte a imagem carregada (img) para um array numpy.
    in_img = tf.keras.preprocessing.image.img_to_array(img)
    
    # Redimensiona a imagem para as dimensões (128, 128, 1) usando o método 'constant' e
    # mantendo o intervalo original.
    in_img = skimage.transform.resize(in_img, (128, 128, 1), mode = 'constant', preserve_range = True)
    
    # Normalize a imagem dividindo cada pixel por 255 e atribui a imagem normalizada à n-ésima posição
    # da lista/array X.
    X[n] = in_img / 255.0

# %% [markdown]
# > Pré-Processamento das Máscaras.

# %%
# Itera sobre os índices (n) e os nomes das máscaras (img_name) na lista 'training_mask'.
for n, img_name in enumerate(training_mask):
    
    # Carrega a imagem de máscara do diretório 'dados/train/' com o nome 'img_name' no modo escala de 
    # cinza (grayscale).
    img = tf.keras.preprocessing.image.load_img('dados/train/' + img_name, color_mode = "grayscale")
    
    # Converte a imagem de máscara carregada (img) para um array numpy.
    in_img = tf.keras.preprocessing.image.img_to_array(img)
    
    # Redimensiona a imagem de máscara para as dimensões (128, 128, 1) usando o método 'constant' e 
    # mantendo o intervalo original.
    in_img = skimage.transform.resize(in_img, (128, 128, 1), mode = 'constant', preserve_range = True)
    
    # Normaliza a imagem de máscara dividindo cada pixel por 255 e atribui a imagem de máscara 
    # normalizada à n-ésima posição da lista/array y.
    Y[n] = in_img / 255.0

# %%
# Dividimos os dados em treino e validação.
X_training, X_valid, Y_training, Y_valid = train_test_split(X, Y, test_size = 0.1, random_state = 42)

# %%
len(X_training)
# Out:
# 5071

# %%
len(X_valid)
# Out:
# 564

# %% [markdown]
# ## Arquitetura do Modelo

# %%
# Define uma função chamada 'Conv2D_Block' que aceita um tensor de entrada e um número de filtros.
def Conv2D_Block(input_tensor, n_filters):
    
    # Adiciona uma camada convolucional 2D ao tensor de entrada com o número especificado de filtros,
    # tamanho do kernal (3x3), inicializador 'he_normal' e padding 'same'.
    x = tf.keras.layers.Conv2D(filters = n_filters,
                               kernel_size = (3, 3),
                               kernel_initializer = 'he_normal',
                               padding = 'same')(input_tensor)
    
    # Adiciona uma camada de normalização em lote ao tensor resultante da operação anterior.
    x = tf.keras.layers.BatchNormalization()(x)
    
    # Adiciona uma camada de ativação ReLU ao tensor resultante da operação anterior.
    x = tf.keras.layers.Activation('relu')(x)
    
    # Adiciona outra camada convolucional 2D ao tensor resultante com o número especificado de filtros, 
    # tamanho do kernel (3x3), inicializador 'he_normal' e padding 'same'.
    x = tf.keras.layers.Conv2D(filters = n_filters,
                               kernel_size = (3, 3),
                               kernel_initializer = 'he_normal',
                               padding = 'same')(x)
    
    # Adiciona outra camada de normalização em lote ao tensor resultante da operação anterior.
    x = tf.keras.layers.BatchNormalization()(x)
    
    # Adiciona outra camada de ativação ReLU ao tensor resultante da operação anterior.
    x = tf.keras.layers.Activation('relu')(x)
  
    # Retorna o tensor resultante após todas as operações.
    return x

# %%
# Define uma função chamada 'U_Net' que constrói uma arquitetura U-Net a partir de um tensor 
# de imagem e número de filtros.
def U_Net(img_tensor, n_filters = 16):
    
    # Primeira etapa de contração da U-Net.
    # Aplica o bloco convolucional no tensor da imagem.
    conv1 = Conv2D_Block(img_tensor, n_filters * 1) 
    
    # Realiza pooling para reduzir dimensionalidade.
    pool1 = tf.keras.layers.MaxPooling2D((2, 2))(conv1)    
    
    # Aplica dropout para prevenir overfitting.
    pool1 = tf.keras.layers.Dropout(0.05)(pool1)                 
  
    # Segunda etapa de contração da U-Net.
    conv2 = Conv2D_Block(pool1, n_filters * 2)
    pool2 = tf.keras.layers.MaxPooling2D((2, 2))(conv2)
    pool2 = tf.keras.layers.Dropout(0.05)(pool2)
  
    # Terceira etapa de contração da U-Net.
    conv3 = Conv2D_Block(pool2, n_filters * 4)
    pool3 = tf.keras.layers.MaxPooling2D((2, 2))(conv3)
    pool3 = tf.keras.layers.Dropout(0.05)(pool3)
  
    # Quarta etapa de contração da U-Net.
    conv4 = Conv2D_Block(pool3, n_filters * 8)
    pool4 = tf.keras.layers.MaxPooling2D((2, 2))(conv4)
    pool4 = tf.keras.layers.Dropout(0.05)(pool4)
  
    # Ponto mais profundo da U-Net (não é reduzido posteriormente).
    conv5 = Conv2D_Block(pool4, n_filters * 16)
  
    # Primeira etapa de expansão da U-Net.
    # Operação transposta da convolução.
    pool6 = tf.keras.layers.Conv2DTranspose(n_filters * 8, (3, 3), (2, 2), padding = 'same')(conv5) 
    
    # Concatena com a saída convolucional da etapa correspondente de contração.
    pool6 = tf.keras.layers.concatenate([pool6, conv4])                                         
    pool6 = tf.keras.layers.Dropout(0.05)(pool6)
    conv6 = Conv2D_Block(pool6, n_filters * 8)
  
    # Segunda etapa de expansão da U-Net.
    pool7 = tf.keras.layers.Conv2DTranspose(n_filters * 4, (3, 3), (2, 2), padding = 'same')(conv6)
    pool7 = tf.keras.layers.concatenate([pool7, conv3])
    pool7 = tf.keras.layers.Dropout(0.05)(pool7)
    conv7 = Conv2D_Block(pool7, n_filters*4)
  
    # Terceira etapa de expansão da U-Net.
    pool8 = tf.keras.layers.Conv2DTranspose(n_filters * 2, (3, 3), (2, 2), padding = 'same')(conv7)
    pool8 = tf.keras.layers.concatenate([pool8, conv2])
    pool8 = tf.keras.layers.Dropout(0.05)(pool8)
    conv8 = Conv2D_Block(pool8, n_filters*2)
  
    # Quarta etapa de expansão da U-Net.
    pool9 = tf.keras.layers.Conv2DTranspose(n_filters * 1, (3, 3), (2, 2), padding = 'same')(conv8)
    pool9 = tf.keras.layers.concatenate([pool9, conv1])
    pool9 = tf.keras.layers.Dropout(0.05)(pool9)
    conv9 = Conv2D_Block(pool9, n_filters * 1)
  
    # Camada de saída.
    # Usa uma camada convolucional para produzir a saída final.
    output = tf.keras.layers.Conv2D(1, (1, 1), activation = 'sigmoid')(conv9)  
    
    # Monta o modelo U-Net usando o tensor de imagem como entrada e a saída calculada.
    u_net = tf.keras.Model(inputs = [img_tensor], outputs = [output])
  
    return u_net

# %%
# Tensor de input
img_tensor = tf.keras.layers.Input((128, 128 , 1), name = 'img')

# %%
# Cria o modelo
modelo = U_Net(img_tensor)

# %%
# Use esta opção para outros processadores
modelo.compile(optimizer = tf.keras.optimizers.Adam(), 
                        loss = 'binary_crossentropy', 
                        metrics = ['accuracy'])

# %%
modelo.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ img (InputLayer)    │ (None, 128, 128,  │          0 │ -                 │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 128, 128,  │        160 │ img[0][0]         │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 128, 128,  │         64 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 128, 128,  │      2,320 │ activation[0][0]  │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 64, 64,    │          0 │ activation_1[0][… │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 64, 64,    │          0 │ max_pooling2d[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 64, 64,    │      4,640 │ dropout[0][0]     │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 64, 64,    │      9,248 │ activation_2[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 32, 32,    │          0 │ activation_3[0][… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 32, 32,    │          0 │ max_pooling2d_1[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 32, 32,    │     18,496 │ dropout_1[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 32, 32,    │     36,928 │ activation_4[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 16, 16,    │          0 │ activation_5[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 16, 16,    │          0 │ max_pooling2d_2[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 16, 16,    │     73,856 │ dropout_2[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 16, 16,    │    147,584 │ activation_6[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 8, 8, 128) │          0 │ activation_7[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 8, 8, 128) │          0 │ max_pooling2d_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 8, 8, 256) │    295,168 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 8, 8, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 8, 8, 256) │    590,080 │ activation_8[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 8, 8, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 16, 16,    │    295,040 │ activation_9[0][… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 16, 16,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 16, 16,    │          0 │ concatenate[0][0] │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 16, 16,    │    295,040 │ dropout_4[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 16, 16,    │    147,584 │ activation_10[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 32, 32,    │     73,792 │ activation_11[0]… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 32, 32,    │          0 │ concatenate_1[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 32, 32,    │     73,792 │ dropout_5[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 32, 32,    │     36,928 │ activation_12[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 64, 64,    │     18,464 │ activation_13[0]… │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 64)               │            │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 64, 64,    │          0 │ concatenate_2[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 64, 64,    │     18,464 │ dropout_6[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 64, 64,    │      9,248 │ activation_14[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 128, 128,  │      4,624 │ activation_15[0]… │
# │ (Conv2DTranspose)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 32)               │            │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 128, 128,  │          0 │ concatenate_3[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 128, 128,  │      4,624 │ dropout_7[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 128, 128,  │      2,320 │ activation_16[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 128, 128,  │         17 │ activation_17[0]… │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,164,305 (8.26 MB)
#  Trainable params: 2,161,361 (8.24 MB)
#  Non-trainable params: 2,944 (11.50 KB)

# %%
# Callbacks
callbacks = [
    tf.keras.callbacks.EarlyStopping(patience = 10, verbose = 1),
    tf.keras.callbacks.ReduceLROnPlateau(factor = 0.1, patience = 5, min_lr = 0.00001, verbose = 1),
    tf.keras.callbacks.ModelCheckpoint('modelos/modelo.keras', 
                                       verbose = 1, 
                                       save_best_only = True, 
                                       save_weights_only = False)]

# %% [markdown]
# > Agora treinamos o modelo.

# %%
# Hiperparâmetros
batch = 32
num_epochs = 10

# %%
# %%time
hist_treino = modelo.fit(X_training, 
                         Y_training, 
                         batch_size = batch, 
                         epochs = num_epochs, 
                         callbacks = callbacks,
                         validation_data = (X_valid, Y_valid))
# Out:
# Epoch 1/10
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 613ms/step - accuracy: 0.9166 - loss: 0.3537
# Epoch 1: val_loss improved from inf to 0.17400, saving model to modelos/modelo.keras
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 107s 632ms/step - accuracy: 0.9169 - loss: 0.3530 - val_accuracy: 0.9827 - val_loss: 0.1740 - learning_rate: 0.0010
# Epoch 2/10
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 621ms/step - accuracy: 0.9826 - loss: 0.1066
# Epoch 2: val_loss improved from 0.17400 to 0.07276, saving model to modelos/modelo.keras
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 101s 638ms/step - accuracy: 0.9826 - loss: 0.1065 - val_accuracy: 0.9835 - val_loss: 0.0728 - learning_rate: 0.0010
# Epoch 3/10
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 622ms/step - accuracy: 0.9847 - loss: 0.0552
# Epoch 3: val_loss improved from 0.07276 to 0.04401, saving model to modelos/modelo.keras
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 102s 639ms/step - accuracy: 0.9847 - loss: 0.0552 - val_accuracy: 0.9851 - val_loss: 0.0440 - learning_rate: 0.0010
# Epoch 4/10
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 627ms/step - accuracy: 0.9853 - loss: 0.0385
# Epoch 4: val_loss improved from 0.04401 to 0.04062, saving model to modelos/modelo.keras
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 103s 645ms/step - accuracy: 0.9853 - loss: 0.0385 - val_accuracy: 0.9829 - val_loss: 0.0406 - learning_rate: 0.0010
# Epoch 5/10
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 653ms/step - accuracy: 0.9857 - loss: 0.0311
# Epoch 5: val_loss improved from 0.04062 to 0.03060, saving model to modelos/modelo.keras
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 107s 671ms/step - accuracy: 0.9857 - loss: 0.0311 - val_accuracy: 0.9842 - val_loss: 0.0306 - learning_rate: 0.0010
# Epoch 6/10
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 674ms/step - accuracy: 0.9861 - loss: 0.0270
# Epoch 6: val_loss improved from 0.03060 to 0.02727, saving model to modelos/modelo.keras
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 110s 692ms/step - accuracy: 0.9861 - loss: 0.0270 - val_accuracy: 0.9854 - val_loss: 0.0273 - learning_rate: 0.0010
# Epoch 7/10
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 647ms/step - accuracy: 0.9864 - loss: 0.0244
# Epoch 7: val_loss improved from 0.02727 to 0.02658, saving model to modelos/modelo.keras
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 106s 665ms/step - accuracy: 0.9864 - loss: 0.0244 - val_accuracy: 0.9853 - val_loss: 0.0266 - learning_rate: 0.0010
# Epoch 8/10
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 627ms/step - accuracy: 0.9861 - loss: 0.0235
# Epoch 8: val_loss did not improve from 0.02658
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 102s 643ms/step - accuracy: 0.9861 - loss: 0.0235 - val_accuracy: 0.9807 - val_loss: 0.0347 - learning_rate: 0.0010
# Epoch 9/10
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 638ms/step - accuracy: 0.9866 - loss: 0.0216
# Epoch 9: val_loss improved from 0.02658 to 0.02508, saving model to modelos/modelo.keras
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 104s 655ms/step - accuracy: 0.9866 - loss: 0.0216 - val_accuracy: 0.9850 - val_loss: 0.0251 - learning_rate: 0.0010
# Epoch 10/10
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 648ms/step - accuracy: 0.9867 - loss: 0.0203
# Epoch 10: val_loss did not improve from 0.02508
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 106s 665ms/step - accuracy: 0.9867 - loss: 0.0203 - val_accuracy: 0.9848 - val_loss: 0.0252 - learning_rate: 0.0010
# CPU times: user 2h 59min 38s, sys: 1min 10s, total: 3h 48s
# Wall time: 17min 27s

# %%
# Plot
plt.figure(figsize = (8, 8))
plt.title("Curva de Aprendizado")
plt.plot(hist_treino.history["loss"], label = "Erro em Treino")
plt.plot(hist_treino.history["val_loss"], label = "Erro em Validação")
plt.plot(np.argmin(hist_treino.history["val_loss"]), 
         np.min(hist_treino.history["val_loss"]), 
         marker = "x", 
         color = "r", 
         label = "Melhor Modelo")
plt.xlabel("Epochs")
plt.ylabel("log_loss")
plt.legend();

# %%
# Carrega a imagem do disco
modelo.load_weights('modelos/modelo.keras')

# %%
# Avalia o modelo
modelo.evaluate(X_valid, Y_valid, verbose = 1)
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - accuracy: 0.9849 - loss: 0.0249
# [0.025081895291805267, 0.9849914908409119]

# %%
# Previsão em Validação
plt.imshow(Y_valid[0].squeeze())

# %% [markdown]
# ## Uso do Modelo com Novas Imagens

# %%
# Define nova imagem e faz o mesmo pré-processamento feito em dados de treino
img_name = '3291.tif'
img = tf.keras.preprocessing.image.load_img('dados/test/' + img_name, color_mode = "grayscale")
in_img = tf.keras.preprocessing.image.img_to_array(img)
in_img = skimage.transform.resize(in_img , (128 , 128 , 1), mode = 'constant', preserve_range = True)
test = in_img / 255.0
plt.imshow(test.squeeze())

# %%
# Previsão
prediction = modelo.predict(np.expand_dims(test , 0))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step

# %%
# Shape
prediction.shape
# Out:
# (1, 128, 128, 1)

# %%
# Ajusta o shape
prediction.squeeze().shape
# Out:
# (128, 128)

# %%
# Plot
fig , ax = plt.subplots(1 , 2)
fig.suptitle('Segmentação de Imagens com IA')
ax[0].set_title('Nova Imagem')
ax[1].set_title('Máscara Prevista')
img1 = test.squeeze()
ax[0].imshow(img1, cmap = 'gray')

img2 = prediction.squeeze()
img2 = np.ma.masked_where(img2 == 0, img2)
ax[1].imshow(img1, cmap = 'gray' , interpolation = 'none')
ax[1].imshow(img2, cmap = 'jet', interpolation = 'none', alpha = 0.7)

plt.show()

# %%
# Define nova imagem e faz o mesmo pré-processamento feito em dados de treino
img_name = '5115.tif'
img = tf.keras.preprocessing.image.load_img('dados/test/' + img_name , color_mode = "grayscale")
in_img = tf.keras.preprocessing.image.img_to_array(img)
in_img = skimage.transform.resize(in_img , (128 , 128 , 1), mode = 'constant', preserve_range = True)
test = in_img / 255.0
plt.imshow(test.squeeze())

# Previsão
prediction = modelo.predict(np.expand_dims(test , 0))

# Ajusta o shape
prediction.squeeze().shape

# Plot
fig , ax = plt.subplots(1 , 2)
fig.suptitle('Segmentação de Imagens com IA')
ax[0].set_title('Nova Imagem')
ax[1].set_title('Máscara Prevista')
img1 = test.squeeze()
ax[0].imshow(img1, cmap = 'gray')

img2 = prediction.squeeze()
img2 = np.ma.masked_where(img2 == 0, img2)
ax[1].imshow(img1, cmap = 'gray' , interpolation = 'none')
ax[1].imshow(img2, cmap = 'jet', interpolation = 'none', alpha = 0.7)

plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
